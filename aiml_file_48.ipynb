# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya9900/git25/blob/main/aiml_file_48.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
exam_data={'name':['manish','dhiraj','man','dhir'],
          'score':[12.5,91,20.5,19]}
df=pd.DataFrame(exam_data)
medium=['english','hindi','hindi','english',]
df['medium']=medium
print("\ new DataFrame after inserting'medium'column")
print(df)
# Out:
# \ new DataFrame after inserting'medium'column
#      name  score   medium
# 0  manish   12.5  english
# 1  dhiraj   91.0    hindi
# 2     man   20.5    hindi
# 3    dhir   19.0  english

# %%
import matplotlib.pyplot as plt
categories = ['Category A', 'Category B', 'Category C']
amounts = [25, 50, 30]
plt.bar(categories, amounts)
plt.xlabel('Categories')
plt.ylabel('Amounts')
plt.title('Bar Chart of Amounts by Category')
plt.grid(True)
plt.show()

# %%
import pandas as pd
iris=pd.read_csv('')
x=iris['sepal length']
y=iris['sepal width']
plt.scatter(x,y)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('scatter plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
iris=pd.read_csv('/content/flowers.csv')
x=iris['sepal length']
y=iris['sepal width']
plt.hist(x,y,bins=10,color='blue',edgecolor='black')
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.title('histogram')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-26-351960919.py in <cell line: 0>()
#       4 x=iris['sepal length']
#       5 y=iris['sepal width']
# ----> 6 plt.hist(x,y,bins=10,color='blue',edgecolor='black')
#       7 plt.xlabel('sepal length')
#       8 plt.ylabel('sepal width')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# TypeError: hist() got multiple values for argument 'bins'

# %%
import matplotlib.pyplot as plt
import numpy as np
low, high = 0, 10
data = np.random.uniform(low, high, 100)
plt.hist(data, bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of a Uniform Distribution')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,30,40,50]
y=[50,40,30,25,85]
plt.scatter(x,y)

# %%
data ={'Name':['Tom', 'nick', 'krish', 'jack'], 'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data)

# %%
import pandas as pd
lst = ['Apple', 'Mango', 'Banana', 'Pine Apple', 'Grapes', 'Watermelon']
df = pd.DataFrame(lst)
print(df)
# Out:
#             0
# 0       Apple
# 1       Mango
# 2      Banana
# 3  Pine Apple
# 4      Grapes
# 5  Watermelon

# %%
data ={'Name':['Tom', 'nick', 'krish', 'jack'], 'Age':[20, 21, 19, 18]}
df = pd.DataFrame(data)

# %%
import pandas as pd
data = {
    'Department': ['HR',  'IT',  'Finance'],
    'Employee': ['Alice', 'Bob', 'Charlie'],
    'Salary': [50000, 55000, 60000,],
    'Age': [25, 30, 28, ]
}
grouped = df.groupby('Department')['Salary'].mean()
print(grouped)
grouped = df.groupby('Department')['Salary'].agg(['mean', 'max', 'min'])
print(grouped)
df['Location']=['Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi']
grouped = df.groupby(['Department', 'Location'])['Salary'].mean()
print(grouped)

df = pd.DataFrame(data)
print(df)
# Out:
# Department
# Finance    60000.0
# HR         50000.0
# IT         55000.0
# Name: Salary, dtype: float64
#                mean    max    min
# Department
# Finance     60000.0  60000  60000
# HR          50000.0  50000  50000
# IT          55000.0  55000  55000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-15-4172643620.py in <cell line: 0>()
#      10 grouped = df.groupby('Department')['Salary'].agg(['mean', 'max', 'min'])
#      11 print(grouped)
# ---> 12 df['Location']=['Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi']
#      13 grouped = df.groupby(['Department', 'Location'])['Salary'].mean()
#      14 print(grouped)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
# ...

# %%
result = df.groupby('Department').agg({
    'Salary': 'mean',
    'Age': ['min', 'max']
})
print(result)
# Out:
#              Salary Age
#                mean min max
# Department
# Finance     60000.0  28  28
# HR          50000.0  25  25
# IT          55000.0  30  30

# %%
import pandas as pd
df = pd.read_csv('/content/excel1.csv')
df.to_csv('output.csv',index=False)
print(df)
df.head()
df.tail()
df.info()
df.columns
df.shape
df.describe()
print(df['name'])
print(df.loc[0])
print(df.iloc[1])
# Out:
#    no    name  m1  m2
# 0   1   manju  25  58
# 1   2   sanju  24  75
# 2   3  shreya  28  95
# 3   4     sam  95  85
# 4   5   radha  63  65
# 5   6   vijji  84  85
# 6   7    tani  45  78
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   no      7 non-null      int64
#  1   name    7 non-null      object
#  2   m1      7 non-null      int64
#  3   m2      7 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 356.0+ bytes
# 0     manju
# 1     sanju
# 2    shreya
# 3       sam
# 4     radha
# 5     vijji
# 6      tani
# Name: name, dtype: object
# no          1
# name    manju
# m1         25
# m2         58
# Name: 0, dtype: object
# no          2
# name    sanju
# m1         24
# m2         75
# Name: 1, dtype: object

# %%
import pandas as pd
data=pd.Series([10,20,30,40]),index=['a', 'b', 'c', 'd'])
print(data)
# Out:
#   File "/tmp/ipython-input-11-182989195.py", line 2
#     data=pd.Series([10,20,30,40]),index=['a', 'b', 'c', 'd'])
#                                                             ^
# SyntaxError: unmatched ')'

# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr.sum())
# Out:
# 10

# %%
import numpy as np
arr=np.array([1,2,3,4])
print(arr.mean())
# Out:
# 2.5

# %%
import numpy as np
import random
array=np.random.randint(4,size=(1,1))
print("input array:\n",array)
print("smallest number in x axis:,",np.min(array,axis=1))
print("smallest number in y axis:,",np.min(array,axis=0))
# Out:
# input array:
#  [[3]]
# smallest number in x axis:, [3]
# smallest number in y axis:, [3]

# %%
import pandas as pd
data={
    'name':['rupa','sita','geeta'],
    'age':[25,30,35],
    'city':['bagalkot','solapur','gulbarag']
}
df=pd.DataFrame(data)
count_c=df['city'].value_counts()
print(count_c)
# Out:
# city
# bagalkot    1
# solapur     1
# gulbarag    1
# Name: count, dtype: int64

# %%
arr = np.array([1, 2, 3])
print(arr + 2)
# Out:
# [3 4 5]

# %%
import pandas as pd
data={
    'name':['rupa','sita','geeta'],
    'age':[25,30,35],
    'city':['bagalkot','solapur','gulbarag'],
    'salary':[50000,60000,70000]
}
df=pd.DataFrame(data)
max_S=df[df['salary']==df['salary'].max()]
print(max_S)
# Out:
#     name  age      city  salary
# 2  geeta   35  gulbarag   70000

# %%
arr = np.array([1, 2, 3])
print(arr + 2)
# Out:
# [3 4 5]

# %%
import pandas as pd
numbers=pd.Series([10,20,30,40,50])
mean_value=numbers.mean()
std_dev=numbers.std()
print("mean:",mean_value)
print("standard deviation:",std_dev)
# Out:
# mean: 30.0
# standard deviation: 15.811388300841896

# %%
print(np.sin(arr))
# Out:
# [0.84147098 0.90929743 0.14112001]

# %%
arr = np.array([1, 2, 3])
arr2 = np.array([1, 2, 3])
print(arr + arr2)

# %%
import pandas as pd
sub1=pd.Series({'alice':85,'bob':78,'charlie':92})
sub2=pd.Series({'alice':88,'bob':82,'david':75})
total_marks=sub1.add(sub2,fill_value=0)
print(total_marks)
# Out:
# alice      173.0
# bob        160.0
# charlie     92.0
# david       75.0
# dtype: float64

# %%
import pandas as pd
timestamps=pd.Series(pd.to_datetime(['2025-01-15','2025-05-22','2025-07-14','2025-12-3']))
months=timestamps.dt.month
print(months)
month_names=timestamps.dt.month_name()
print(month_names)
# Out:
# 0     1
# 1     5
# 2     7
# 3    12
# dtype: int32
# 0     January
# 1         May
# 2        July
# 3    December
# dtype: object

# %%
import pandas as pd
data=pd.Series({'a':10,'b':50,'c':30,'d':40})
max_index=data.idxmax()
print("index of maximun value:",max_index)
# Out:
# index of maximun value: b

# %%
import pandas as pd
data={
    'name':['rupa','sita','geeta'],
    'age':['25','30','35'],
    'city':['bagalkot','solapur','gulbarag']
}
df=pd.DataFrame(data)
print(df)
# Out:
#     name age      city
# 0   rupa  25  bagalkot
# 1   sita  30   solapur
# 2  geeta  35  gulbarag

# %%
import pandas as pd
data={
    'name':['rupa','sita','geeta'],
    'age':['25','30','35'],
    'city':['bagalkot','solapur','gulbarag']
}
df=sorted=df.sort_values(by='age',ascending = false)
print(df_sorted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-64-1136784556.py in <cell line: 0>()
#       5     'city':['bagalkot','solapur','gulbarag']
#       6 }
# ----> 7 df=sorted=df.sort_values(by='age',ascending = false)
#       8 print(df_sorted)
#
# NameError: name 'false' is not defined

# %%
import pandas as pd
fruit_Series=pd.Series({'apple':50,'banana':30,'cherry':20})
increased_prices=fruit_Series*1.2
new_Series=pd.Series({'banana':10,'cherry':5,'data':15})
combined_Series=increased_prices+new_Series
print(combined_Series)
# Out:
# apple      NaN
# banana    46.0
# cherry    29.0
# data       NaN
# dtype: float64

# %%
import pandas as pd
s1=pd.Series([5,10,15,20,25])
print(s1)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
s.index=['a','b','c','d','e']
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
import pandas as pd
import numpy as np
exam_data={'name':['manish','dhiraj','man','dhir'],
           'score':[12.5,91,20.5,19]}
df=pd.DataFrame(exam_data)
df=df.rename(columns={'name':'name','score':'score'})
print("new DataFrame after renaming columns:")
print(df)
# Out:
# new DataFrame after renaming columns:
#      name  score
# 0  manish   12.5
# 1  dhiraj   91.0
# 2     man   20.5
# 3    dhir   19.0

# %%
import pandas as pd
import numpy as np
exam_data={'name':['manish','dhiraj','man','dhir'],
           'score':[12.5,91,20.5,19]}
df=pd.DataFrame(exam_data)
df=df[df.score>=20]
print("new DataFrame")
print(df)
# Out:
# new DataFrame
#      name  score
# 1  dhiraj   91.0
# 2     man   20.5

# %%
import pandas as pd
import numpy as np
s1=pd.Series(['100','200','400'])
s2=pd.Series(['10','20','40'])
print("DataFrame:")
print(s1)
print(s2)
df=pd.concat([s1,s2],axis=1)
print("new DataFrame combining two Series:")
print(df)
# Out:
# DataFrame:
# 0    100
# 1    200
# 2    400
# dtype: object
# 0    10
# 1    20
# 2    40
# dtype: object
# new DataFrame combining two Series:
#      0   1
# 0  100  10
# 1  200  20
# 2  400  40

# %%
import pandas as pd
import numpy as np
s1=pd.Series(['100','200','400'])
s2=pd.Series(['10','20','40'])
df=pd.concat([s1,s2],axis=1)
print("value of row4")
print(df.iloc[2])
# Out:
# value of row4
# 0    400
# 1     40
# Name: 2, dtype: object

# %%
import pandas as pd
import numpy as np
s1=pd.Series(['100','200','400'])
s2=pd.Series(['10','20','40'])
df=pd.concat([s1,s2],axis=1)
new_col=[1,2,3]
idx=0
df.insert(loc=idx,column='1',value=new_col)
print("\n new DataFrame")
print(df)
# Out:
#  new DataFrame
#    1    0   1
# 0  1  100  10
# 1  2  200  20
# 2  3  400  40

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.normal(0, 1, 1000)
data2 = np.random.normal(2, 1, 1000)
sns.boxplot(data=[data1, data2])
plt.xlabel('Distribution')
plt.ylabel('Value')
plt.title('Box Plot Comparison of Two Distributions')
plt.show()

# %%
import pandas as pd
mtcars=pd.read_csv('/content/mtcars (2).csv')
mtcars
# Out:
#          mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb  fast  \
# 0   4.582576    6  160.0  110  3.90  2.620  16.46   0   1     4     4     1
# 1   4.582576    6  160.0  110  3.90  2.875  17.02   0   1     4     4     1
# 2   4.774935    4  108.0   93  3.85  2.320  18.61   1   1     4     1     1
# 3   4.626013    6  258.0  110  3.08  3.215  19.44   1   0     3     1     1
# 4   4.324350    8  360.0  175  3.15  3.440  17.02   0   0     3     2     1
# 5   4.254409    6  225.0  105  2.76  3.460  20.22   1   0     3     1     1
# 6   3.781534    8  360.0  245  3.21  3.570  15.84   0   0     3     4     0
# 7   4.939636    4  146.7   62  3.69  3.190  20.00   1   0     4     2     1
# 8   4.774935    4  140.8   95  3.92  3.150  22.90   1   0     4     2     1
# 9   4.381780    6  167.6  123  3.92  3.440  18.30   1   0     4     4     1
# 10  4.219005    6  167.6  123  3.92  3.440  18.90   1   0     4     4     1
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
mtcars=pd.read_csv('/content/mtcars (2).csv')
plt.hist(mtcars['mpg'],bins=10,color='lightgreen',edgecolor='black')
plt.xlabel('mpg')
plt.ylabel('frequency')
plt.title('distibution of the variable mpg')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
mtcars=pd.read_csv('/content/mtcars (2).csv')
x=mtcars['wt']
y=mtcars['mpg']
plt.scatter(x,y)
plt.xlabel("wt")
plt.ylabel("mpg")
plt.title("scatter plot")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.DataFrame({'transmission':['manual','auto','auto','manual','auto']})
mtcars=pd.read_csv('/content/mtcars (2).csv')
df['transmission'].value_counts().plot(kind='bar',color='blue')
plt.title('transmission type frequency')
plt.xlabel('transmission')
plt.ylabel('count')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
mtcars=pd.read_csv('/content/mtcars (2).csv')
mpg=mtcars['mpg'].unique()
data=[mtcars[mtcars]['mpg'==m]['mpg']for m in mpg]
plt.boxplot(data,labels=mpg)
plt.xlabel("mpg")
plt.ylabel("miles per gallon")
plt.title("compare miles per gallon between mpg")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3119925580.py in <cell line: 0>()
#       3 mtcars=pd.read_csv('/content/mtcars (2).csv')
#       4 mpg=mtcars['mpg'].unique()
# ----> 5 data=[mtcars[mtcars]['mpg'==m]['mpg']for m in mpg]
#       6 plt.boxplot(data,labels=mpg)
#       7 plt.xlabel("mpg")
#
# /tmp/ipython-input-3119925580.py in <listcomp>(.0)
#       3 mtcars=pd.read_csv('/content/mtcars (2).csv')
#       4 mpg=mtcars['mpg'].unique()
# ----> 5 data=[mtcars[mtcars]['mpg'==m]['mpg']for m in mpg]
#       6 plt.boxplot(data,labels=mpg)
#       7 plt.xlabel("mpg")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4087         # Do we have a (boolean) DataFrame?
#    4088         if isinstance(key, DataFrame):
# -> 4089             return self.where(key)
#    4090
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
mtcars=pd.read_csv('/content/mtcars (2).csv')
plt.boxplot(df['mpg'])
plt.title("box plot of mpg")
plt.ylabel("Miles per Gallon")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1806037474.py in <cell line: 0>()
#       2 import pandas as pd
# ...
